# %% [markdown]
# # Latin to Lao transformation
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/enabling-languages/libraries-transformation/blob/main/notebooks/ALA_LC_transformations.ipynb)

# %% [markdown]
# ## Setup

# %%
#@title
#%%capture
#!pip install -q unicodedataplus
#!pip install -q regex
#!pip install -q grapheme
#!pip install -q laonlp
#!pip install -q pythainlp
#!pip install -q python-crfsuite
#!pip install -q pyicu
#!wget -q https://raw.githubusercontent.com/enabling-languages/libraries-transformation/main/el_transliteration.py -O /content/el_transliteration.py
#!wget -q https://raw.githubusercontent.com/enabling-languages/libraries-transformation/main/el_utils.py -O /content/el_utils.py

# pip install -U git+https://github.com/enabling-languages/el_internationalisation.git#egg=el_internationalisation
# pip install -U git+https://github.com/enabling-languages/el_utilities.git#egg=el_utilities

import el_utilities as elu

# %% [markdown]
# ## Latin to Lao transformation

# %%
# Test:     Vīangchan : Hǭ Samut hæng Sāt, 2006.
latn_input_str = input("String to transform: ")
laoo_output_str = elu.el_transliterate(latn_input_str, lang="lo", dir="reverse", nf="NFM")
print("\n")
print(latn_input_str)
print(laoo_output_str)
# Out:
# Vīangchan : Hǭ Samut Hæng Sāt, 2006.
# ວຽງຈັນ : ຫໍ ສະມຸດ hæng ຊາດ, 2006.

# %% [markdown]
# ## Lao to Latin transformation

# %%
lang = "lo"
if lang == "lo":
    from laonlp.tokenize import word_tokenize
import el_internationalisation as eli
import regex as re

# Test:  ວຽງຈັນ : ຫໍສະມຸດແຫ່ງຊາດ, 2006.
laoo_input_str_orig = input("String to transform: ")
laoo_input_str = laoo_input_str_orig
# laoo_input_str = word_tokenize(laoo_input_str)

# %%
print(laoo_input_str)
# pattern = r'(\p{Lao}+)'
LANG = "lo"
pattern = {
    'lo': r'(\p{Lao}+)'
}
# replacement = " ".join(word_tokenize(r'\1'))

# https://stackoverflow.com/questions/12597370/python-replace-string-pattern-with-output-of-function
def replacement(match):
    if LANG == "lo":
        #match = match.group()
        return " ".join(word_tokenize(match.group()))

laoo_input_str = re.sub(pattern[LANG], replacement, laoo_input_str)
print(laoo_input_str)
# Out:
# ວຽງຈັນ : ຫໍສະມຸດ ແຫ່ງຊາດ, 2006.
# ວຽງຈັນ : ຫໍສະມຸດ ແຫ່ງຊາດ, 2006.

# %%
latn_output_str = elu.el_transliterate(laoo_input_str, lang="lo", dir="forward", nf="nfd")
print("\n")
print(laoo_input_str)
print(latn_output_str)
# Out:
# ວຽງຈັນ : ຫໍສະມຸດ ແຫ່ງຊາດ, 2006.
# Vīangchan : HǭSamut hǣngSāt, 2006.

# %%
from icu import BreakIterator, Locale, RuleBasedBreakIterator
LANG = "lo-LA"
LOC = Locale.createCanonical(LANG)

def iterate_breaks(text, break_iterator):
    break_iterator.setText(text)
    lastpos = 0
    while True:
        next_boundary = break_iterator.nextBoundary()
        if next_boundary == -1: return
        yield text[lastpos:next_boundary]
        lastpos = next_boundary

# SEP = "\u2009·\u2009"
SEP = " "
def results(l, sep="|", pymyan=False):
    print("Number of tokens: ", str(len(l)))
    r = sep.join(list(s['syllable'] for s in l)) if pymyan else sep.join(l)
    print("Segmentation boundaries: " + r)

# %%
laoo_input_str2 = laoo_input_str_orig

wbi = BreakIterator.createWordInstance(LOC)
# words_icu = list(iterate_breaks(laoo_input_str2, wbi))
# results(words_icu, sep=" ")

def lao_replace_icu(match):
    #match = match.group()
    return SEP.join(list(iterate_breaks(match.group(), wbi)))

laoo_input_str2 = re.sub(pattern['lo'], lao_replace_icu, laoo_input_str2)
print(laoo_input_str2)
# Out:
# ວຽງຈັນ : ຫໍ ສະມຸດ ແຫ່ງຊາດ, 2006.

# %%
latn_output_str2 = elu.el_transliterate(laoo_input_str2, lang="lo", dir="forward", nf="nfd")
print(laoo_input_str_orig)
print(laoo_input_str2)
print(latn_output_str2)
# Out:
# ວຽງຈັນ : ຫໍສະມຸດແຫ່ງຊາດ, 2006.
# ວຽງຈັນ : ຫໍ ສະມຸດ ແຫ່ງຊາດ, 2006.
# Vīangchan : Hǭ Samut hǣngSāt, 2006.

# %% [markdown]
# ### Trankit
#
# ```zsh
# pip install trankit
# ```

# %%
from trankit import Pipeline, supported_langs
print(supported_langs)
# Out:
# ['afrikaans', 'ancient-greek-perseus', 'ancient-greek', 'arabic', 'armenian', 'basque', 'belarusian', 'bulgarian', 'catalan', 'chinese', 'traditional-chinese', 'classical-chinese', 'croatian', 'czech-cac', 'czech-cltt', 'czech-fictree', 'czech', 'danish', 'dutch', 'dutch-lassysmall', 'english', 'english-gum', 'english-lines', 'english-partut', 'estonian', 'estonian-ewt', 'finnish-ftb', 'finnish', 'french', 'french-partut', 'french-sequoia', 'french-spoken', 'galician', 'galician-treegal', 'german', 'german-hdt', 'greek', 'hebrew', 'hindi', 'hungarian', 'indonesian', 'irish', 'italian', 'italian-partut', 'italian-postwita', 'italian-twittiro', 'italian-vit', 'japanese', 'kazakh', 'korean', 'korean-kaist', 'kurmanji', 'latin', 'latin-perseus', 'latin-proiel', 'latvian', 'lithuanian', 'lithuanian-hse', 'marathi', 'norwegian-nynorsk', 'norwegian-nynorsklia', 'norwegian-bokmaal', 'old-french', 'old-russian', 'persian', 'polish-lfg', 'polish', 'portuguese', 'portuguese-gsd', 'romanian-nonstandard', 'romanian', 'russian-gsd', 'russian', 'russian-taiga', 'scottish-gaelic', 'serbian', 'slovak', 'slovenian', 'slovenian-sst', 'spanish', 'spanish-gsd', 'swedish-lines', 'swedish', 'tamil', 'telugu', 'turkish', 'ukrainian', 'urdu', 'uyghur', 'vietnamese', 'vietnamese-vtb']

# %% [markdown]
# ---

# %%
# dict1 = OrderedDict(sorted(dict.items()))
lang="lo"
translit_table = elu.SUPPORTED_TRANSLITERATORS[lang]
# w_dict = elu.transliteration_data[translit_table[0]]['translit_dict']['forward']
from collections import OrderedDict
#word_dict = OrderedDict(sorted(w_dict.items(), reverse=True))
from icu import Collator, Locale
lang = "lo"
lang_collator = Collator.createInstance(Locale(lang))
root_collator = Collator.createInstance(Locale.getRoot())

word_dict = OrderedDict(sorted(elu.TRANSLIT_DATA[translit_table[0]]['translit_dict']['forward'].items(), reverse=True, key=lambda x: lang_collator.getSortKey(x[0])))
word_dict = {elu.normalise("nfd", k): elu.normalise("nfc", v) for k, v in word_dict.items()}
word_dict
# Out:
# {'ໂຮມ': 'hōm',
#  'ໂຮງຮຽນ': 'Hōnghīan',
#  'ໂຮງພິມ': 'Hōngphim',
#  'ແຮງງານ': 'hǣnngān',
#  'ແຮກ': 'hǣk',
#  'ເຮົາ': 'hao',
#  'ຮຽບຮຽງ': 'līaplīang',
#  'ຮູບພາບ': 'Hūppāp',
#  'ຮູບປັ້ນ': 'hūppan',
#  'ຮູບ': 'hūp',
#  'ຮຸ່ງ': 'Hung',
#  'ຮືອນ': 'hūʼan',
#  'ຮິບໂຮມ': 'hiphōm',
#  'ຮ່ຳຮຽນ': 'hamhīan',
#  'ຮ່າໂນ້ຍ': 'Hānōi',
#  'ຮ້ານນາຍໄຊຍ໌': 'Rānnāisai',
#  'ຮັບ': 'hap',
#  'ຮັນສ໌': 'Han',
#  'ຮັກສາ': 'Haksā',
#  'ຮັກ': 'hak',
#  'ຮອບ': 'hǭp',
#  'ຮອດບຸນ': 'Hǭtbun',
#  'ຮ້ອຍ': 'Hǭi',
#  'ຮ່ວມສະໄໜ': 'hūamsamai',
#  'ຮວບຮວມໂດຍ': 'Hūaphūam',
#  'ໂອກາດ': 'ʻōkāt',
#  'ເອົາ': 'ʻao',
#  'ເອກະສານ': 'ʻēkasān',
#  'ອົບຮົມ': 'ʻophom',
#  'ອົງການ': 'ʻOngkān',
#  'ອຸໄທ': 'ʻUthai',
#  'ອຸດົມການ': 'ʻudomkān',
#  'ອຸດສາຫະກຳ': 'ʻUtsāhakam',
#  'ອຶນ': 'U̕n',
#  'ອີງໃສ່': 'ʻīngsai',
#  'ອິນທະວົງສ໌': 'ʻInthavong',
#  'ອິນສີຊຽງໃໝ່': 'ʻInsīsīangmai',
#  'ອຳນາດ': 'ʻamnāt',
#  'ອຳທິລອ': 'ʻAmthilǭ',
#  'ອາຣຸນ': 'ʻĀrun',
#  'ອາຣ': 'ʻĀr',
#  'ອານາຈັກ': 'ʻānāchak',
#  'ອານັນໂທ': 'ʻĀnanthō',
#  'ອາຈານໃຫຍ່': 'ʻĀchānnyai',
#  'ອາຈານ': 'ʹĀchān',
#  'ອ່າ': 'ʻān',
#  'ອັພຍຍສັພທ໌': 'ʻapphayasap',
#  'ອັນ': 'ʻAn',
#  'ອັດຕາ': 'ʻattā',
#  'ອັກສອນສິລປ໌': 'ʻaksǭnsin',
#  'ອັກຂຣະວິທີ': 'ʻAkkharavithī',
#  'ອະລຸນ': 'ʻAlun',
#  'ອະນຸວົງ': 'ʻAnuvong',
#  'ອະນຸສາວະລີ': 'ʻanusāvalī',
#  'ອໍລະບູນ': 'ʻǬlabūn',
#  'ໄຫ້': 'hai',
#  'ໃຫຍ່': 'Nyai',
#  'ໂຫຣາສາດ': 'hōrāsāt',
#  'ແຫ່ງ': 'hǣng',
#  'ເຫຼັ້ມ': 'Lem',
#  'ເຫດການ': 'hētkān',
#  'ເຫງື່ອ': 'ngư̄a',
#  'ຫຼຽວ': 'līeo',
#  'ຫຼວງພຣະບາງ': 'Lūangphrabāng',
#  'ຫົວໃຈ': 'hūachai',
#  'ຫົວຂໍ້': 'hūakhǭ',
#  'ຫົງເຫີນ': 'Honghœ̄n',
#  'ຫົງສາຄອນ': 'Hongsākhǭn',
#  'ຫົງສາ': 'Hongsā',
#  'ຫາຍ': 'hāi',
#  'ຫ້າ': 'hā',
#  'ຫັດທະຈັນ': 'Hatthachan',
#  'ຫອມ': 'Hǭm',
#  'ຫ້ອງສມຸດ': 'Hǭngsamut',
#  'ຫ້ອງ': 'Hǭng',
#  'ຫລານ': 'lān',
#  'ຫລວງວັນນາ': 'Lūangvannā',
#  'ຫລວງລາດ': 'Lūanglāt',
#  'ຫລວງ': 'Lūang',
#  'ໃໝ່': 'Mai',
#  'ໝູ່ບ້ານ': 'mūbān',
#  'ໝູນແກ້ວ': 'Mūnkǣo',
#  'ໜຸຸ່ມ': 'Num',
#  'ໜຶ່ງ': 'nưng',
#  'ຫຍຸ້ງຍາກ': 'nyungyāk',
#  'ຫຍໍ້': 'nyǭ',
#  'ຫໍ': 'Hǭ',
#  'ໄວຍາກອນ': 'Vainyākǭn',
#  'ເວີ່ນວິລາວົງ': 'Vœ̄nvīlāvong',
#  'ເວທີ': 'vēthī',
#  'ເວດສັນດອນ': 'Vētsandǭn',
#  'ວຽດນາມ': 'Vīatnām',
#  'ວຽງໄຊ': 'Vīangsai',
#  'ວຽງຈັນ': 'Vīangchan',
#  'ວຽງ': 'Vīang',
#  'ວຽກງານ': 'vīakngān',
#  'ວົງວິຈິດ': 'Vongvichit',
#  'ວົງສິນ': 'Vongsin',
#  'ວົງກິດ': 'ʻAngkit',
#  'ວົງ': 'Vong',
#  'ວີລະຊົນ': 'vīlason',
#  'ວີຣະວົງສ໌': 'Vīravong',
#  'ວິວັດ': 'vivat',
#  'ວິໄນ': 'vinai',
#  'ວິທີ': 'vithī',
#  'ວິທະຍາສາດ': 'Vithanyāsāt',
#  'ວິຖີທຳ': 'Vithītham',
#  'ວິຖີຄົນ': 'vithīkhon',
#  'ວິຊາ': 'Visā',
#  'ວິສາຫະກິດ': 'Visāhakit',
#  'ວິຈິດສິນ': 'Vichitsin',
#  'ວາລະສາມ': 'Vālasān',
#  'ວາຣະສານ': 'Vārasān',
#  'ວ່າດ້ວຍ': 'Vādūai',
#  'ວ່າການ': 'Vākān',
#  'ວ່າ': 'vā',
#  'ວັນນິພາ': 'Vanniphā',
#  'ວັນນະສິນ': 'Vannasin',
#  'ວັນນະຄຳ': 'vannakam',
#  'ວັນນະຄະດີ': 'vannakhadī',
#  'ວັນທີ': 'vanthī',
#  'ວັນໄຊ': 'Vansai',
#  'ວັນສ້າງ': 'vansāng',
#  'ວັດທະນະທຳ': 'vatthanatham',
#  'ວັດຈະນານຸກົມ': 'Vatchanānukom',
#  'ວັດ': 'Vat',
#  'ວະຊິຣະຍານະວິສຸທທິ': 'Vajirañāṇavisuddhi',
#  'ວະຈີວິພາກ': 'Vachīviphāk',
#  'ວໍລະຈິດ': 'Vǭlachit',
#  'ວໍຣະຈິດ': 'Vǭrachit',
#  'ໄລຍະ': 'lainya',
#  'ແລະ': 'læ',
#  'ເລື່ອງ': 'lư̄ang',
#  'ເລືອກ': 'lư̄ak',
#  'ລົມ': 'Lom',
#  'ລູກດອນກະເດັນ': 'Lūkdǭnkaden',
#  'ລູກສິດ': 'lūksit',
#  'ລຶບລ້າງ': 'Lưplāng',
#  'ລາວດວງເດືອນ': 'Lāodūangdư̄an',
#  'ລາວ': 'Lāo',
#  'ລານຄຳ': 'Lānkham',
#  'ລ້ານ': 'Lān',
#  'ລາດຊະວົງ': 'lātsavong',
#  'ລາດສະດອນ': 'lātsadǭn',
#  'ລາຍຕ່ຳ': 'Lāitam',
#  'ລາຍງານ': 'Lāingān',
#  'ລັດທະຍົດ': 'Latthayot',
#  'ລັດຖະບານ': 'Latthabān',
#  'ລັດ': 'Lat',
#  'ລະບຽບ': 'labīap',
#  'ລະດັບ': 'ladap',
#  'ລໍເບຼຍຢາວ': 'Lǭbrīayāo',
#  'ຣາຊອານາຈັກ': 'Rātsaʻānāchak',
#  'ຣາຊບັນດິຕສະພາລາວ': 'Rātsabanditsaphā',
#  'ຣາຊບັນດິຕ': 'Rātbandit',
#  'ຣາຊບັນດິດ': 'Rātsabandit',
#  'ຣັດຕະນະກະວີ': 'Rattanakavī',
#  'ເຢຊູ': 'Yēsū',
#  'ຢູ່': 'yū',
#  'ຢອດ': 'yǭt',
#  'ໄມ່ສິງ': 'Maising',
#  'ແມ່ບົດ': 'mǣbot',
#  'ແມ່ຍິງ': 'Mǣnying',
#  'ແມງໄມ້': 'Mǣngmai',
#  'ແມງ': 'mǣng',
#  'ແມ່': 'mǣ',
#  'ເມືອງພວນ': 'Mư̄angphūan',
#  'ເມືອງ': 'Mư̄ang',
#  'ເມທີວໍຣະຄຸນ': 'Mēthīvǭrakhun',
#  'ເມສາ': 'Mēsā',
#  'ມູນນິທິ': 'Mūnnithi',
#  'ມູນແຖນແຕ່ງ': 'Mūnthǣntæng',
#  'ມູນເຊື້ອ': 'mūnsư̄a',
#  'ມຸງຄຸລເ': 'mungkhun',
#  'ມຸ່ງ': 'mung',
#  'ມືນ': 'Mư̄n',
#  'ມີ': 'mī',
#  'ມິຖຸນາ': 'Mithunā',
#  'ມາລາວົງ': 'Mālāvong',
#  'ມາ': 'mā',
#  'ມັດທາວ': 'Matthāi',
#  'ມັດທະຍົມສຶກສາ': 'Matthayomsưksā',
#  'ມັດທະຍົມ': 'matthayom',
#  'ມະໂຫສົດ': 'Mahōsot',
#  'ມະຫາຊາລີ': 'Mahāsālī',
#  'ມະຫາ': 'Mahā',
#  'ມໍລະດົກ': 'mǭladok',
#  'ມ.': 'Mǭ.',
#  'ໄຟຟ້າ': 'faifā',
#  'ໄຟດ່າງ': 'Faidāng',
#  'ໄຟ': 'Fai',
#  'ຟ້າງຸ່ມ': 'Fāngum',
#  'ໄພວັນ': 'Phivan',
#  'ໂພນ': 'Phōn',
#  'ແພງ': 'Phǣng',
#  'ເພື່ອ': 'Phua',
#  'ເພັຊ': 'phet',
#  'ເພັງແສງຄຳ': 'Phengsǣngkham',
#  'ພົບ': 'phop',
#  'ພົງສາວະດານ': 'phongsāvadān',
#  'ພູມີ': 'Phūmī',
#  'ພູທອນ': 'phūthǭn',
#  'ພຸທທະໂຄສະໂກ': 'Phutthakhōsakō',
#  'ພຸດທະສາສະນາ': 'Phutthasātsanā',
#  'ພື້ນເມືອງ': 'phư̄nmư̄ang',
#  'ພິລາວົງສ໌': 'Philāvong',
#  'ພິລະອາດຫານ': 'philaʻāthān',
#  'ພິມພັນທະວົງ': 'Phimphanthavong',
#  'ພິມ': 'phim',
#  'ພິທີກຳ': 'phithīkam',
#  'ພາບ': 'phāp',
#  'ພາຍໃຕ້': 'phāitai',
#  'ພາສີ': 'phāsī',
#  'ພາສາສາດ': 'phāsāsāt',
#  'ພາສາ': 'phāsā',
#  'ພາກ': 'Phāk',
#  'ພັດທະນາ': 'Phatthanā',
#  'ພັກ': 'Phak',
#  'ພະລານໄຊ': 'Phalānsai',
#  'ພະພຸດທະສາສະນາ': 'Phaphutthasāsanā',
#  'ພະບາງ': 'Phabāng',
#  'ພະແນກ': 'Phanǣk',
#  'ພະຈິກ': 'Phachik',
#  'ພະຄຼິທະສາສນາ': 'Phakhitthasātsanā',
#  'ພະຄຳພີ': 'Phakhamphi',
#  'ພະ': 'Pha',
#  'ພ້ອມດ້ວຍ': 'phǭmdūai',
#  'ພອນແກ້ວ': 'Phǭnkǣo',
#  'ພອນກະເສີມສຸກ': 'Phǭnkasœ̄msuk',
#  'ພວງດອກຊ້ອນ': 'Phūangdǭksǭn',
#  'ພຣະຣາຊອ': 'Phrarātsa',
#  'ພຣະເມົາ': 'phranao',
#  'ພຣະປຣິຍັດຕິທັມ': 'phraparinyattitham',
#  'ພຣະ': 'Phra',
#  'ພ.ສ.': 'Phǭ.Sǭ.',
#  'ພ': 'Phǭ',
#  'ຝັນ': 'fan',
#  'ຝຣັ່ງເສດ': 'Farangsēt',
#  'ຝຣັ່ງ': 'farang',
#  'ແຜນແມ່ບົດ': 'Phǣnmǣbot',
#  'ແຜນທີ່': 'phǣnthī',
#  'ແຜ່ນດິນ': 'phǣndin',
#  'ແຜນການ': 'Phǣnkān',
#  'ແຜນ': 'Phǣn',
#  'ເຜົ່າ': 'phao',
#  'ຜົນໄດ້ຮັບ': 'phondaihap',
#  'ຜົນງານ': 'phonngān',
#  'ຜົນກະທົບ': 'phonkathop',
#  'ຜົນ': 'phon',
#  'ຜູ້ຮິບໂຮມ': 'phūhiphōm',
#  'ຜູ້ແທນ': 'Phūthǣn',
#  'ຜູ້': 'Phū',
#  'ຜິວລາວັນ': 'Phiulāvan',
#  'ຜ້າແພ': 'phāphǣ',
#  'ຜາບັກກຳ': 'Phābakkham',
#  'ຜ່ານ': 'phān',
#  'ຜະຫຍາກອນ': 'Phanyākǭn',
#  'ແປດສິບ': 'Pǣtsip',
#  'ແປງ': 'pǣng',
#  'ແປ': 'pǣ',
#  'ເປ້າໝາຍ': 'paomāi',
#  'ເປັນ': 'pen',
#  'ປົກປັກ': 'Pokpak',
#  'ປົກຄອງ': 'pokkhǭng',
#  'ປູ່': 'pū',
#  'ປຸກໃຈ': 'pukchai',
#  'ປຶ້ມ': 'pư̄m',
#  'ປີ': 'pī',
#  'ປານຄຳ': 'Pānkham',
#  'ປານ': 'Pān',
#  'ປາແດກ': 'Pādǣk',
#  'ປາສມໍ': 'Pāsamǭ',
#  'ປາງຄຳ': 'Pāngkham',
#  'ປາກປາສັກ': 'Pākpāsak',
#  'ປ້າ': 'pā',
#  'ປັນປຸງ': 'pappung',
#  'ປັນຍາສິລິ': 'Pannyāsili',
#  'ປະໂຫຍກ': 'payōk',
#  'ປະຫວັດສາດ': 'Pavatsāt',
#  'ປະຫວັດ': 'Pavat',
#  'ປະລິນດາ': 'Palindā',
#  'ປະເມີນຜົນ': 'Pamœ̄nphon',
#  'ປະມວນ': 'Pamūan',
#  'ປະເພນີ': 'paphēnī',
#  'ປະພັນ': 'paphan',
#  'ປະເທດ': 'Pathēt',
#  'ປະຕິວັດ': 'Pativat',
#  'ປະຕິບັດ': 'patibat',
#  'ປະຕິທິນ': 'patithin',
#  'ປະຊາທິປະໄຕ': 'Pasāthipatai',
#  'ປະຊາຊົນ': 'Pasāson',
#  'ປະເສິດ': 'Pasœ̄t',
#  'ປະສົມ': 'Pasom',
#  'ປະສິດທິພາບ': 'pasitthiphāp',
#  'ປະສິດທິຜົນ': 'pasitthiphon',
#  'ປະຈຳ': 'pacham',
#  'ປະກອບ': 'pakǭp',
#  'ປຮະເສີດ': 'Prasœ̄t',
#  'ປອງດອງ': 'Pǭngdǭng',
#  'ປ້ອງກັນ': 'Pǭngkan',
#  'ປຣຽນ': 'parīan',
#  'ປຣະດິດ': 'Pradit',
#  'ໃບໂພ': 'Baiphō',
#  'ແບບ': 'Bǣp',
#  'ເບີຕັນ': 'Bœ̄tan',
#  'ເບີເກີ': 'Bœ̄kœ̄',
#  'ເບິ່ງ': 'bœ̄ng',
#  'ບົວໄລ': 'Būalai',
#  'ບົວບາງບຶງ': 'Būabāngbưng',
#  'ບົດຮຽນ': 'Bothīan',
#  'ບົດຄວາມ': 'Botkhwām',
#  'ບົດກະວີ': 'botkavī',
#  'ບົດກອນ': 'botkǭn',
#  'ບົດ': 'Bot',
#  'ບູຮານ': 'būhān',
#  'ບຸນເລືອ': 'Bunlư̄a',
#  'ບຸນເລີງ': 'Bunlœ̄ng',
#  'ບຸນທັມ': 'Buntham',
#  'ບຸນທະນອງ': 'Bunthanǭng',
#  'ບຸນຍາວົງ': 'Bunnyāvong',
#  'ບຸນຍະພອນ': 'Bunnyaphǭn',
#  'ບຸນກວ້າງ': 'Bunkwāng',
#  'ບຸນ': 'bun',
#  'ບາລີໄ': 'Bālī',
#  'ບ້ານນາ': 'bānnā',
#  'ບາງ': 'bāng',
#  'ບັນຫາ': 'banhā',
#  'ບັນນາທິການ': 'bannāthikān',
#  'ບັນທຶກ': 'banthưk',
#  'ບັນຊີ': 'Bansī',
#  'ບອລເມີ': 'Bǭnmœ̄',
#  'ບ່ອນ': 'bǭn',
#  'ບອກ': 'bǭk',
#  'ບໍ່': 'bǭ',
#  'ໃນ': 'nai',
#  'ເນື້ອໃນ': 'nư̄anai',
#  'ເນື່ອງໃນ': 'Nūangnai',
#  'ເນື່ອງ': 'nư̄ang',
#  'ເນດຕະວົງ': 'Nēttavong',
#  'ນິວັດ': 'Nivat',
#  'ນິທານ': 'Nithān',
#  'ນິຕິກຳ': 'nitikam',
#  'ນິຍົມໄທ': 'Niyomthai',
#  'ນຳ': 'nam',
#  'ນາມ': 'nām',
#  'ນາປາກແຕນ': 'Nāpāktǣn',
#  'ນາງ': 'Nāng',
#  'ນັກຮຽນ': 'nakhīan',
#  'ນັກປະພັນ': 'Nakpaphan',
#  'ນັກຂຽນ': 'Nakkhīan',
#  'ນັກກະວີ': 'nakkavī',
#  'ນັກ': 'Nak',
#  'ນະຄອນ': 'Nakhǭn',
#  'ນໜັງສື': 'nangsư̄',
#  'ນໍຣະສິລປ໌': 'Nǭrasin',
#  'ເທື່ອ': 'thư̄a',
#  'ເທບສິດທາ': 'Thēpsitthā',
#  'ເທບ': 'Thēp',
#  'ເທສນາ': 'Thētsanā',
#  'ທຽບໃສ່': 'thīapsai',
#  'ທົ່ວ': 'thūa',
#  'ທົງສະຫວາດ': 'Thongsavāt',
#  'ທຸກຍາກ': 'thuknyāk',
#  'ທຸກ': 'thuk',
#  'ທີ່ຫັ້ນ': 'thīhan',
#  'ທີ': 'thī',
#  'ທິດາຈັນ': 'Thidāchan',
#  'ທິດສະດີ': 'Thitsadī',
#  'ທຳມະເທວາ': 'Thammathēvā',
#  'ທຳມະຊາດ': 'thammasāt',
#  'ທຳມະການ': 'Thammakān',
#  'ທຳດີ': 'Thamdi',
#  'ທ້າວ': 'Thāo',
#  'ທ່ານນາງ': 'Thānnāng',
#  'ທ່ານ': 'Thān',
#  'ທາງ': 'Thāng',
#  'ທັມມະທານ': 'thammathān',
#  'ທັມ': 'tham',
#  'ທັນວາ': 'Thanvā',
#  'ທັດສະນະວິຈານ': 'thatsanavichān',
#  'ທະວີສຸກ': 'Thavīsuk',
#  'ທະວາວາ': 'Thavāvā',
#  'ທະສະຊາຕະກະ': 'Thasasātaka',
#  'ທລຍ': 'Thǭ Lǭ Nyǭ',
#  'ເຖິງ': 'thœ̄ng',
#  'ຖືກຕ້ອງ': 'thư̄ktǭng',
#  'ຖາວອນ': 'thāvǭn',
#  'ຖານທີ່ໝັ້ນ': 'thānthīman',
#  'ຖານ': 'thān',
#  'ແຕ້ມ': 'tǣm',
#  'ແຕ່ງ': 'tæng',
#  'ເຕັກນິກ': 'teknik',
#  'ເຕມິຍະ': 'Tēmiya',
#  'ຕົວ': 'tūa',
#  'ຕິດຕາມ': 'Tittām',
#  'ຕຳນານ-ພົງສາວະດານ': 'Tamnān-phongsāvadān',
#  'ຕາມ': 'tām',
#  'ຕ້ານ': 'Tān',
#  'ຕາແສງ': 'tāsǣng',
#  'ຕ່າງໆ': 'tāng tāng',
#  'ຕາ': 'tā',
#  'ຕອບ': 'tǭp',
#  'ຕ່ອຕ້ານ': 'tǭtān',
#  'ໃດ': 'dai',
#  'ໂດຍ': 'dōi',
#  'ເດືອນ': 'Dư̄an',
#  'ເດີນທາງ': 'Dœ̄nthāng',
#  'ເດດວົງພັນ': 'Dētvongphan',
#  'ດົນຕຣື': 'dontrī',
#  'ດີເດັ່ນ': 'dīden',
#  'ດາຣາ': 'Dārā',
#  'ດ້ານ': 'dān',
#  'ດອກເກດ': 'Dǭkkēt',
#  'ດອກ': 'dǭk',
#  'ດວງພະສຸກ': 'Dūangphasuk',
#  'ດວງເດືອນ': 'Dūangdư̄an',
#  'ດວງຈຳປາ': 'Dūangchampā',
#  'ດຣ.': 'Dǭ Rǭ',
#  'ຍຸຕິທຳ': 'Yuttitham',
#  'ຍຶດ': 'yưt',
#  'ຍິນ': 'nyin',
#  'ຍອດ': 'nyǭt',
#  'ໄຊຍະວົງ': 'Saiyavong',
#  'ໄຊຍະບູລີ': 'Sainyabulī',
#  'ໄຊຊະນະ': 'Xaixana',
#  'ເຊື່ອມໂຍງ': 'Sư̄amnyōng',
#  'ເຊິ່ງ': 'sœ̄ng',
#  'ຊົມໄຊຜົນ': 'Somsaiphon',
#  'ຊົນນະບົດ': 'sonnabot',
#  'ຊຸດ': 'sut',
#  'ຊື້ເທີດ': 'Sư̄thœ̄t',
#  'ຊີວິດ': 'sīvit',
#  'ຊີໄຣທ໌': 'Sīrrai',
#  'ຊຳຣະ': 'samra',
#  'ຊາວ': 'sāo',
#  'ຊາລີ': 'Sālī',
#  'ຊາປະນະກິດ': 'sāpanakit',
#  'ຊາຕະກະ': 'sātaka',
#  'ຊາດົກ': 'sādok',
#  'ຊາດ': 'Sāt',
#  'ຊ່າງຊ່ຽນ': 'sāngsīan',
#  'ຊັບພະຍາກອນ': 'sapphanyākǭn',
#  'ຊັ້ນ': 'San',
#  'ຊະນົກ': 'Sanok',
#  'ໄສ': 'Sai',
#  'ແສງສຸວັນ': 'Sǣngsuvan',
#  'ເສື້ອ': 'sư̄a',
#  'ເສັ້ນທາງ': 'sēnthāng',
#  'ສຽງ': 'sīang',
#  'ສົມພະວັນ': 'Somphavan',
#  'ສົມພອນ': 'Somphǭn',
#  'ສົມບູນຂັນ': 'Sombūnkhan',
#  'ສົມທົບ': 'somthop',
#  'ສົມທະເຜີຍ': 'Somthaphœ̄i',
#  'ສົມແສງ': 'Somsǣng',
#  'ສົມໃຈ': 'Somchai',
#  'ສົບ': 'sop',
#  'ສົນທິ': 'sonthi',
#  'ສົກ': 'sok',
#  'ສູນກາງ': 'Sūnkāng',
#  'ສູນ': 'Sūn',
#  'ສູ່': 'sū',
#  'ສຸວັນນະພັນ': 'Suvannaphan',
#  'ສຸລິ': 'Suli',
#  'ສຸບັນ': 'Suban',
#  'ສຸຂີ': 'Sukhī',
#  'ສຸກອານັນສັກ': 'Sukʻānansak',
#  'ສຸກສະຫວັນ': 'Suksavan',
#  'ສຶກສາທິການ': 'Sưksāthikān',
#  'ສຶກສາ': 'sưksā',
#  'ສີວົງສັກ': 'Sīvongsak',
#  'ສີລາເພັດ': 'Sīlāped',
#  'ສີຜົມໄຊຍ໌': 'Sīphomsai',
#  'ສີບຸນເຮືອງ': 'Sībunhư̄ang',
#  'ສີສຸວັນນະ': 'Sīsuvanna',
#  'ສີສັນ': 'Sīsan',
#  'ສີຂຽວ': 'Sīkhīeo',
#  'ສີ': 'sī',
#  'ສິລິພອນ': 'Siliphǭn',
#  'ສິລາ': 'Silā',
#  'ສິນລະປິນ': 'sinlapin',
#  'ສິດທິມະນຸດ': 'sitthimanut',
#  'ສິດທິເດດ': 'Sitthidēt',
#  'ສິງຫາ': 'singhā',
#  'ສິ່ງແວດລ້ອມ': 'singvǣtlǭm',
#  'ສິຄຳ': 'Sīkham',
#  'ສຳລັບ': 'samlap',
#  'ສຳມະນາ': 'sammanā',
#  'ສຳພາດ': 'samphāt',
#  'ສຳນັກພິມ': 'Samnakphim',
#  'ສຳນວນ': 'samnūan',
#  'ສາລະບານ': 'Sālabān',
#  'ສາມັນ': 'sāman',
#  'ສາມັກຄີ': 'Sāmakkhī',
#  'ສານປະເສິດ': 'Sānpasœt',
#  'ສາທາລະນະລັດ': 'Sāthālanalat',
#  'ສ້າງສັນ': 'Sāngsan',
#  'ສ້າງ': 'Sāng',
#  'ສາຂາ': 'sākhā',
#  'ສາກົນ': 'sākon',
#  'ສັບ': 'sap',
#  'ສັນຕິພາບ': 'santiphāp',
#  'ສັນຍາ': 'sannyā',
#  'ສັດຈັງເວ': 'Satchangvē',
#  'ສັງລວມ': 'Sanglūam',
#  'ສັງຄົມນິຍົມ': 'Sangkhomninyom',
#  'ສັງຄົມ': 'Sangkhom',
#  'ສັງເຂບ': 'sangkhēp',
#  'ສັງຂ໌ສິລປ໌ຊັຍ': 'Sangsinsai',
#  'ສະເຫຼີມສະຫຼອງ': 'ngānsalœ̄msalǭng',
#  'ສະເຫລິມສະຫລອງ': 'salœ̄msalǭng',
#  'ສະຫຼອງ': 'salǭng',
#  'ສະຫະພັນ': 'Sahāphan',
#  'ສະຫວ່າງ': 'lavāng',
#  'ສະຫວັນນະເກດ': 'Savannakhet',
#  'ສະໄໝ': 'samāi',
#  'ສະໝຸນໄພ': 'Samunphai',
#  'ສະໜັບສະໜູນ': 'sanapsanūn',
#  'ສະຫງວນ': 'Sangūan',
#  'ສະມຸດ': 'Samut',
#  'ສະມາຊິກ': 'samāsik',
#  'ສະມາຄົມ': 'Sammakhom',
#  'ສະພາ': 'Sapā',
#  'ສະບັບ': 'sabap',
#  'ສະນາຄົມ': 'Samākhom',
#  'ສະຖາບັນ': 'Sathāban',
#  'ສະສົມ': 'sasom',
#  'ສອນໄຊ': 'Sǭnsai',
#  'ສອນ': 'sǭn',
#  'ສອງ': 'sǭng',
#  'ສວຍງາມ': 'sūaingām',
#  'ສມບູນ': 'Sombūn',
#  'ສປປ': 'SǭPǭPǭ',
#  'ສ': 'Sǭ',
#  'ໃຈ': 'chai',
#  'ເຈົ້າພາບ': 'chaophāp',
#  'ເຈົ້າ': 'Chao',
#  'ເຈືອງ': 'Chư̄ang',
#  'ເຈ': 'Chē',
#  'ຈຶ່ງ': 'chưng',
#  'ຈີນ': 'Chīn',
#  'ຈຳໜ່າຍ': 'Chamnāi',
#  'ຈຳປານະຄອນ': 'Champānakhǭn',
#  'ຈຳປາ': 'Champā',
#  'ຈາກ': 'chāk',
#  'ຈັນບຸດີ': 'Chanbudī',
#  'ຈັນທະວົງ': 'Chanthavong',
#  'ຈັນທະໄພນູນ': 'Chanthaphaibūn',
#  'ຈັນທະສຸຊາດ': 'Chanthasusāt',
#  'ຈັນທະຈັກ': 'Chanthachak',
#  'ຈັນດີ': 'Chandī',
#  'ຈັດພິມ': 'Chatphim',
#  'ຈັດທຳ': 'chattham',
#  'ຈັດຕັ້ງ': 'Chattang',
#  'ຈັດ': 'chat',
#  'ຈະ': 'cha',
#  'ຈອນ': 'Chǭn',
#  'ຈ.ສ.': 'Chǭ.Sǭ.',
#  'ງາມ': 'ngām',
#  'ງານ': 'ngān',
#  'ໂຄສະນາ': 'Khōsanā',
#  'ໂຄງການ': 'Khōngkān',
#  'ຄົບຮອບ': 'khophǭp',
#  'ຄົບ': 'khop',
#  'ຄົ້ນຄວ້າ': 'Khonkhwā',
#  'ຄົນ': 'khon',
#  'ຄູ່ມື': 'khūmư̄',
#  'ຄູນມະນີ': 'Khūnmanī',
#  'ຄຳຮຸ່ງ': 'Khamhung',
#  'ຄຳຫຼ້າ': 'Khamlā',
#  'ຄຳວອນ': 'Khamvǭn',
#  'ຄຳເມິງ': 'Khammœ̄ng',
#  'ຄຳເພົາ': 'Khamphao',
#  'ຄຳພີ': 'khamphī',
#  'ຄຳພ້ອງ': 'Khamphǭng',
#  'ຄຳຜຸນ': 'Khamphun',
#  'ຄຳທວາຍ': 'Khamthawāi',
#  'ຄຳຖາມ': 'khamthām',
#  'ຄຳຕອບ': 'khamtǭp',
#  'ຄຳສັບ': 'khamsap',
#  'ຄຳກອນ': 'khamkǭn',
#  'ຄຳກອງ': 'Khamkǭng',
#  'ຄຳ': 'kham',
#  'ຄັ້ງ': 'khang',
#  'ຄະນະ': 'Khana',
#  'ຄອມມູນິດ': 'Khǭmmūnit',
#  'ຄວາມຮັກ': 'khwāmhak',
#  'ຄວາມໝາຍ': 'khwāmmāi',
#  'ຄວາມເປັນມາ': 'khwāmpenmā',
#  'ຄວາມເປັນກາງ': 'khwāmpenkāng',
#  'ຄວາມທຸກຍາກ': 'khwāmthuknyāk',
#  'ຄວາມທຸກ': 'khwāmthuk',
#  'ຄວາມຍືນຍງ': 'khwāmnyư̄nnyong',
#  'ຄວາມຊົງຈຳ': 'khwāmsongcham',
#  'ຄວາມສະເໜຫາ': 'khwāmsanēhā',
#  'ຄວາມສອດຄ່ອງ': 'khwāmsǭtkhǭng',
#  'ຄວາມເຈັບປວດ': 'Khwamcheppūat',
#  'ຄນິຕສາດ': 'khanitsāt',
#  'ຄ.ພ.ພ': 'Khǭ.Phǭ.Phǭ.',
#  'ແຂວງ': 'Khwǣng',
#  'ເຂົ້າມາ': 'khaomā',
#  'ເຂົ້າໃຈ': 'Khaochai',
#  'ເຂົ້າ': 'khao',
#  'ຂຽນ': 'khīan',
#  'ຂົງເຂດ': 'khongkhēt',
#  'ຂຸນພິທັກ': 'Khunphithak',
#  'ຂຶ້ນ': 'khưn',
#  'ຂີ້': 'Khī',
#  'ຂ່າວສານ': 'Khāosān',
#  'ຂະບວນ': 'khabūan',
#  'ຂອບໃຈ': 'Khǭpchai',
#  'ຂອງ': 'khǭng',
#  'ໃກ້': 'kai',
#  'ເກອກ': 'Kēʻǭk',
#  'ເກຣກໍຣີ': 'Krēkǭrī',
#  'ກ່ຽວກັບ': 'kīeokap',
#  'ກົມ': 'Kom',
#  'ກົດໝາຍ': 'kotmāi',
#  'ກົງພັດ': 'Kongpat',
#  'ກົງເດືອນ': 'Kongdư̄an',
#  'ກຸມມານ': 'kummān',
#  'ກຸ່ມ': 'Kum',
#  'ກຸງ': 'Kung',
#  'ກິມ': 'Kim',
#  'ກິ່ນ': 'Kin',
#  'ກິຕິມະສັກ': 'kitimasak',
#  'ກິແດງ': 'Kidǣng',
#  'ກິ່ງວົງສັກ': 'Kingvongsak',
#  'ກຳມະການ': 'Kammakān',
#  'ກຳພ້າ': 'Kamphā',
#  'ກາບກອບ': 'kāpkǭn',
#  'ກາບ': 'Kāp',
#  'ການລົງທຶນ': 'Kānlongthưn',
#  'ການລຸກຮື້': 'kānlukhư̄',
#  'ການລຶບລ້າງ': 'kānlưplāng',
#  'ການເມືອງ': 'Kānmư̄ang',
#  'ການພິມ': 'Kānphim',
#  'ການພັດທະນາ': 'kānphatthanā',
#  'ການປົກຄອງ': 'Kānpokkhǭng',
#  'ການປະຕິວັດ': 'kānpativat',
#  'ການປະດິດສະຖານ': 'kānpaditsathān',
#  'ການປະຊຸມ': 'kānpasum',
#  'ການບັນຊີ': 'kānbansī',
#  'ການບວດ': 'kānbūat',
#  'ການທະຫານ': 'Kānthahān',
#  'ການທ່ອງທ່ຽວ': 'kānthǭngthīeo',
#  'ການແຕ່ງດອງ': 'kāntængdǭng',
#  'ການຕາຍ': 'kāntāi',
#  'ການຕ່າງປະເທດ': 'Kāntāngpathēt',
#  'ການຕັ້ງຕົ້ນ': 'kāntangton',
#  'ການສູ່ຂວັນ': 'Kānsūkhwan',
#  'ການສຶກສາ': 'Kānsưksā',
#  'ການສຳຫລວດ': 'kānsamlūat',
#  'ການສ້າງ': 'Kānsāng',
#  'ການຈັດຕັ້ງ': 'Kānchattang',
#  'ການເງິນ': 'Kānngœn',
#  'ການເຄືອນໄຫວ': 'kānkhư̄anvai',
#  'ການຄ້າ': 'Kānkhā',
#  'ການຄ້ນຄວ້າ': 'Kānkhonkhwā',
#  'ການເກີດ': 'kānkœ̄t',
#  'ການກໍສ້າງ': 'kānkǭsāng',
#  'ກາງ': 'Kāng',
#  'ກາ': 'kang',
#  'ກັບ': 'kap',
#  'ກັນລະຍາ': 'Kanlayā',
#  'ກັນຕະສິໂລ': 'Kantasilō',
#  'ກັນຍາ': 'kanyā',
#  'ກັນ': 'kan',
#  'ກະວີນິພົນ': 'kavīniphǭn',
#  'ກະວີ': 'kavī',
#  'ກະຊວງ': 'Kasūang',
#  'ກະກຽນ': 'kakīan',
#  'ກອມມູນິດ': 'Kǭmmūnit',
#  'ກອນລຳ': 'Kǭnlam',
#  'ກອນເຕີຍ': 'Kǭntīa',
#  'ກ່ອນ': 'Kǭn',
#  'ກອງປະຊຸມ': 'Kǭngpasum',
#  'ກອງທຶນຫລຸດຜ່ອນ': 'Kǭngthưnlutphǭn',
#  'ກອງ': 'kǭng',
#  'ກວດທານ': 'kūathān',
#  'ກວດສອບ': 'kūatsǭp',
#  'ກວດແກ້': 'kūatkǣ',
#  'ກໍ່': 'kǭ'}

# %%
import pdir
pdir(elu)
# Out:
# property:
#     DEFAULT_NF, SUPPORTED_TRANSLITERATORS, TRANSLIT_DATA, __author__, __builtins__, __credits__, __version__, re
# module attribute:
#     __cached__, __file__, __loader__, __name__, __package__, __path__, __spec__
# special attribute:
#     __doc__
# class:
#     Collator: Collator objects
#     Locale: Locale objects
#     OrderedDict: Dictionary that remembers insertion order
# function:
#     el_transliterate:
#     normalise:
#     prep_string:
